# %% [markdown]
# <a href="https://colab.research.google.com/github/Jannatu37/Simulation-and-Modeling-Lab03/blob/main/Simulation_and_Modeling_Lab03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
random_vector = np.random.rand(10)
print(random_vector)
# Out:
# [0.29014504 0.29562466 0.22895821 0.48618704 0.03175201 0.89462933
#  0.72647882 0.33046324 0.77516833 0.75636782]

# %%
import matplotlib.pyplot as plt
random_vector = np.random.rand(10)
plt.hist(random_vector, bins=20, edgecolor='black',color='gray')
plt.title('Histogram of 1x10 Vector of Random Numbers')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
random_numbers = np.random.randn(500)
print(random_numbers)
# Out:
# [ 2.83889160e-01  5.48921296e-01 -7.45699206e-01 -7.64136424e-01
#   1.37492991e+00  1.14349315e-02  1.07795590e+00 -1.06817692e+00
#   3.12944785e-02 -1.43185079e+00  3.28656173e-01  1.54881914e+00
#   2.23246593e-01 -5.90300234e-01  2.10148388e+00  1.02012277e+00
#  -1.33077614e+00 -7.05389972e-02 -1.46066867e+00  1.50369583e+00
#   2.03645344e+00 -5.25335512e-01 -1.14995729e+00 -5.49466211e-01
#   5.31944748e-01 -3.77767178e-02  5.68047741e-01  4.33629634e-02
#  -3.30430902e-01  1.51645811e-01  4.46252738e-01 -6.90150109e-01
#   1.02554174e+00  1.10513533e+00 -5.17768871e-01  5.45824990e-01
#  -1.35220919e+00 -1.02197511e+00 -4.66550294e-02  1.08423569e-01
#  -5.95710235e-01  3.85916752e-01  1.87048321e-01 -5.85911507e-01
#  -4.24669250e-01 -3.43364000e-02  5.83189109e-01 -8.81575051e-02
#  -4.68889779e-01  3.27255138e-02 -5.71928894e-01  3.18064733e-01
#   6.41469246e-01 -9.14907908e-01  3.85641124e-01 -1.26641629e+00
# ...

# %%
random_numbers = np.random.normal(0,1,500)
plt.hist(random_numbers, bins=50, edgecolor='red', alpha=0.75, color ='green' )
plt.title('Histogram of Random Numbers from Standard Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()
